# %%
import matplotlib as mpl
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# Draw a line in a diagram from position (0,0) to position (6,250):

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# Plotting without line
xpoints = np.array([1, 4, 7, 9, 4, 7, 2])
ypoints = np.array([3, 8, 1, 10, 5, 7, 4])

plt.plot(xpoints, ypoints, 'o')

# %%
plt.plot(xpoints, ypoints)

# %%
plt.plot(xpoints)
plt.show()
plt.plot(ypoints)
plt.show()

# %%
xpoints = np.array([1, 8, 1, 10, 4, 2, 9, 0, 6, 7, 3, 2, 11])
ypoints = np.array([6, 8, 1, 10, 5, 7, 4, 2, 9, 0, 6, 7, 3])

plt.plot(xpoints, ypoints, 'o:r')
plt.show()

# %%
x = np.random.normal(0, 1, 1000)

plt.hist(ypoints, bins=len(ypoints))
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o-.r')
plt.plot(ypoints, marker='o', ms=20, mec='#4CAF50', mfc='#4CAF50')

# %%
plt.plot(ypoints, linestyle='dotted')
plt.show()
plt.plot(ypoints, linestyle='dashed')
plt.show()

# %%
import seaborn as sns
sns.set_style("darkgrid")

tips = sns.load_dataset("tips")

sns.scatterplot(x="total_bill", y="tip", data=tips)
print(tips.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
x1 = np.array([0, 1, 2, 3, 7, 8, 9, 2])
y1 = np.array([3, 8, 1, 10, 3, 1, 9, 7])
x2 = np.array([0, 1, 2, 3, 2, 6, 8, 5])
y2 = np.array([6, 2, 7, 11, 1, 8, 9, 4])
plt.plot(x1, y1, x2, y2, 'o', ms=3, mec='#4CAF50', mfc='#4CAF50')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

# %%
x=[1,2,3,4]
y=[2,4,6,8]

plt.plot(x,y,color='red')

plt.pie([1],colors=['red'])

plt.show()

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)
print(arr.shape)
print(np.__version__)
# Out:
# [1 2 3 4 5]
# (5,)
# 1.24.1

# %%
arr1 = np.ndarray([1, 2, 3, 4, 5])

print(arr1)
print(arr1.dtype)
print(type(arr1))
# Out:
# [[[[[ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       0.00000000e+000  0.00000000e+000]
#     [ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       0.00000000e+000  0.00000000e+000]
#     [ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       1.59112932e-311  1.59112932e-311]
#     [ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       0.00000000e+000  0.00000000e+000]]
#
#    [[ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       0.00000000e+000  0.00000000e+000]
#     [ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       0.00000000e+000  0.00000000e+000]
#     [ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       0.00000000e+000  0.00000000e+000]
#     [ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       0.00000000e+000  0.00000000e+000]]
#
#    [[ 0.00000000e+000  0.00000000e+000  0.00000000e+000
#       0.00000000e+000  0.00000000e+000]
#     [ 0.00000000e+000  0.00000000e+000  0.00000000e+000
# ...
